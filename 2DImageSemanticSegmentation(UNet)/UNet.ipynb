# %% [markdown]
# # NAVARCH 565 FA 24 Homework 4

# %% [markdown]
# ### File Submission Instructions
#
# #### Submit 5 Files:
#
# From Problem 1:
# - `Problem1.py`
# - `YourNet.pth`
# - `Problem1_Predictions.zip`
#
# From Problem 2:
# - `Problem2.py`
# - `Problem2_Predictions.zip`
#
# Please submit the Python files (`Problem1.py`, `Problem2.py`), two zip files of predictions (`Problem1_Predictions.zip`, `Problem2_Predictions.zip`), and one trained network file (`YourNet.pth`) that you will generate from Problem 1. Make sure to name the checkpoint file as **`YourNet.pth`**, as the autograder will look for this specific filename.
#
# Enjoy Scene Understanding!

# %% [markdown]
# # Objectives
#
# This assignment will be more hands-off than the previous perception problems. In the assignment, we will learn about convolutional neural networks and create a U-Net for semantic segmentation of images. You will be free to modify and create your own network. At the end of the assignment, you will generate predictions on a test set and be graded on the mean IoU of your predictions.

# %% [markdown]
# # Grading
# All points from this assignment will come from evaluation on the test set. We will generate predictions on every tenth frame of the test set for submission to the autograder. This problem is worth 50 points including 10 points of extra credit. Points will be assigned by the mIoU metric as
#
# $$
# \text{score} = 60 \frac{\text{mIoU}}{30}
# $$
#
# meaning that a score of 30% will obtain all extra credit, and a score of 25% will obtain full credit.

# %% [markdown]
# # Setup Code
# Before getting started we need to run some boilerplate code to set up our environment. You'll need to rerun this setup code each time you start the notebook.
#
# First, run this cell load the [autoreload](https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html?highlight=autoreload) extension. This allows us to edit `.py` source files, and re-import them into the notebook for a seamless editing and debugging experience.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Google Colab Setup
#
# Next we need to run a few commands to set up our environment on Google Colab.
# Run the following cell to mount your Google Drive. Follow the link, sign in to your Google account.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Now recall the path in your Google Drive where you uploaded this notebook, fill it in below. If everything is working correctly then running the folowing cell should print the filenames from the assignment:
#
# ```
# ['UNet.ipynb',  'Problem2.py', 'Labels.txt']
# ```

# %%
import os

# TODO: Fill in the Google Drive path where you uploaded the assignment
# Example: If you create a hw4/student/ folder and put all the files under UNet folder, then 'student/PointNet'
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = "hw4/student/UNet"
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))
# Out:
# ['Labels.txt', '__pycache__', 'Test', 'Train', 'Val', 'Problem2.py', 'YourNet.pth', 'UNet.ipynb']

# %% [markdown]
# Next we have some standard imports

# %%
import sys
sys.path.append(GOOGLE_DRIVE_PATH)

import time, os
os.environ["TZ"] = "US/Eastern"
time.tzset()

# %%
from Problem2 import *
import torch
import torchvision
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from tqdm import tqdm
import numpy as np

# %% [markdown]
# Next we will check if a GPU is available

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Using device: cuda

# %% [markdown]
# # Data Visualization
#
# In this assignment we will be working with camera images and pixel-wise semantic segmentation labels.
#
# First, download the data from https://curly-dataset-public.s3.us-east-2.amazonaws.com/NA565/UNet/StudentData/Student.zip and unzip it to create a Train, Test, and Val folder. Place the files into a UNet folder and add the path in the cell below. Move the `Labels.txt` file to Data folder.
#
#
#
# Run the cells below to visualize some of the example images from the dataset.

# %%
batch_size = 2
DATA_PATH = os.path.join(GOOGLE_DRIVE_PATH)

trainset = ImageSegmentation(DATA_PATH, "Train", transform=transform_train(), device=device)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, collate_fn=trainset.collate_fn)

valset = ImageSegmentation(DATA_PATH, "Val", transform=transform_test(), device=device)
val_loader = torch.utils.data.DataLoader(valset, batch_size=batch_size,
                                         shuffle=True, collate_fn=valset.collate_fn)

# %%
def imshow(img):
    img = img / 2 + 0.5     # un-normalize
    npimg = img.detach().cpu().numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

def imshow_labels(img):
    npimg = img.detach().cpu().numpy()
    plt.imshow(npimg)
    plt.show()

# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)

# show images
demo_image = images[0, :, :, :]
imshow(demo_image)
# show labels
demo_label = labels[0, :, :, :]
imshow_labels(demo_label)

# %%
import os

print("Contents of DATA_PATH/Train:")
print(os.listdir(os.path.join(DATA_PATH, "Train")))

print("\nContents of DATA_PATH/Train/Labels:")
print(os.listdir(os.path.join(DATA_PATH, "Train", "Labels")))
# Out:
# Contents of DATA_PATH/Train:
# ['Labels', 'Camera']
#
# Contents of DATA_PATH/Train/Labels:
# ['classgt_00241.png', 'classgt_00001.png', 'classgt_00011.png', 'classgt_00022.png', 'classgt_00016.png', 'classgt_00012.png', 'classgt_00006.png', 'classgt_00248.png', 'classgt_00266.png', 'classgt_00260.png', 'classgt_00262.png', 'classgt_00236.png', 'classgt_00267.png', 'classgt_00004.png', 'classgt_00247.png', 'classgt_00244.png', 'classgt_00255.png', 'classgt_00240.png', 'classgt_00230.png', 'classgt_00002.png', 'classgt_00007.png', 'classgt_00245.png', 'classgt_00239.png', 'classgt_00010.png', 'classgt_00250.png', 'classgt_00253.png', 'classgt_00252.png', 'classgt_00265.png', 'classgt_00242.png', 'classgt_00237.png', 'classgt_00227.png', 'classgt_00231.png', 'classgt_00249.png', 'classgt_00232.png', 'classgt_00258.png', 'classgt_00243.png', 'classgt_00261.png', 'classgt_00005.png', 'classgt_00238.png', 'classgt_00257.png', 'classgt_00269.png', 'classgt_00254.png', 'classgt_00009.png', 'classgt_00256.png', 'classgt_00246.png', 'classgt_00000.png', 'classgt_00003.png', 'classgt_00263.png', 'classgt_00268.png', 'classgt_00259.png', 'classgt_00229.png', 'classgt_00251.png', 'classgt_00264.png', 'classgt_00334.png', 'classgt_00042.png', 'classgt_00063.png', 'classgt_00023.png', 'classgt_00292.png', 'classgt_00171.png', 'classgt_00313.png', 'classgt_00301.png', 'classgt_00050.png', 'classgt_00338.png', 'classgt_00014.png', 'classgt_00335.png', 'classgt_00048.png', 'classgt_00331.png', 'classgt_00017.png', 'classgt_00325.png', 'classgt_00020.png', 'classgt_00275.png', 'classgt_00019.png', 'classgt_00294.png', 'classgt_00299.png', 'classgt_00183.png', 'classgt_00204.png', 'classgt_00280.png', 'classgt_00329.png', 'classgt_00081.png', 'classgt_00298.png', 'classgt_00327.png', 'classgt_00049.png', 'classgt_00320.png', 'classgt_00008.png', 'classgt_00306.png', 'classgt_00314.png', 'classgt_00054.png', 'classgt_00196.png', 'classgt_00187.png', 'classgt_00032.png', 'classgt_00278.png', 'classgt_00038.png', 'classgt_00336.png', 'classgt_00068.png', 'classgt_00192.png', 'classgt_00039.png', 'classgt_00044.png', 'classgt_00332.png', 'classgt_00088.png', 'classgt_00083.png', 'classgt_00322.png', 'classgt_00045.png', 'classgt_00197.png', 'classgt_00284.png', 'classgt_00277.png', 'classgt_00272.png', 'classgt_00026.png', 'classgt_00060.png', 'classgt_00168.png', 'classgt_00279.png', 'classgt_00318.png', 'classgt_00291.png', 'classgt_00069.png', 'classgt_00176.png', 'classgt_00076.png', 'classgt_00078.png', 'classgt_00321.png', 'classgt_00070.png', 'classgt_00179.png', 'classgt_00209.png', 'classgt_00216.png', 'classgt_00056.png', 'classgt_00077.png', 'classgt_00075.png', 'classgt_00293.png', 'classgt_00270.png', 'classgt_00073.png', 'classgt_00199.png', 'classgt_00067.png', 'classgt_00290.png', 'classgt_00030.png', 'classgt_00034.png', 'classgt_00025.png', 'classgt_00286.png', 'classgt_00300.png', 'classgt_00333.png', 'classgt_00215.png', 'classgt_00035.png', 'classgt_00207.png', 'classgt_00064.png', 'classgt_00302.png', 'classgt_00182.png', 'classgt_00024.png', 'classgt_00205.png', 'classgt_00036.png', 'classgt_00311.png', 'classgt_00324.png', 'classgt_00328.png', 'classgt_00288.png', 'classgt_00066.png', 'classgt_00174.png', 'classgt_00059.png', 'classgt_00065.png', 'classgt_00170.png', 'classgt_00058.png', 'classgt_00202.png', 'classgt_00052.png', 'classgt_00041.png', 'classgt_00281.png', 'classgt_00282.png', 'classgt_00037.png', 'classgt_00085.png', 'classgt_00200.png', 'classgt_00178.png', 'classgt_00283.png', 'classgt_00312.png', 'classgt_00273.png', 'classgt_00084.png', 'classgt_00189.png', 'classgt_00047.png', 'classgt_00184.png', 'classgt_00276.png', 'classgt_00317.png', 'classgt_00285.png', 'classgt_00208.png', 'classgt_00194.png', 'classgt_00018.png', 'classgt_00033.png', 'classgt_00027.png', 'classgt_00080.png', 'classgt_00310.png', 'classgt_00062.png', 'classgt_00304.png', 'classgt_00198.png', 'classgt_00309.png', 'classgt_00271.png', 'classgt_00053.png', 'classgt_00185.png', 'classgt_00072.png', 'classgt_00051.png', 'classgt_ ...

# %% [markdown]
# Notice how the ground truth is a color-coded image? The cell below takes the colors and converts each color to an integer label for our network to learn.

# %%
label_file = open(os.path.join(DATA_PATH, "Labels.txt"), "r")
class_dict = {}

i = 0
label_file.readline()
for line in label_file:
    text = line.split("\n")[0]
    tokens = text.split(" ")
    rgb = np.array([int(tokens[1]), int(tokens[2]), int(tokens[3])])
    class_dict[i] = rgb
    i += 1

# Convert colored image to labels
def to_labels(label_img, color_to_label):
    B, H, W, C = label_img.shape
    labels = torch.zeros((B, H, W, 1), device=label_img.device)
    for i, rgb in color_to_label.items():
        mask = (label_img[:, :, :, 0] == rgb[0]) & (label_img[:, :, :, 1] == rgb[1]) & (label_img[:, :, :, 2] == rgb[2])
        labels[mask] = i
    return labels

# %% [markdown]
# ## Training
#
# The following cell trains a network on the semantic segmentation data. Copy your `IoU` function from the previous assignment into `Problem2.py` so we can judge performance on the IoU score.
#
#
# We provide a basic starter network `UNetStudent` which you will need to modify to get a full score. Try training the default network once, then making your own modifications to the network.

# %%
def train_net_iou(net, trainloader, val_loader, device, num_epochs, optimizer, criterion):
  for epoch in range(num_epochs):  # loop over the dataset multiple times
      # Train
      net.train()
      total_loss = 0
      i = 0
      loop = tqdm(trainloader)
      for data in loop:
          # get the inputs; data is a list of [inputs, labels]
          inputs, labels = data

          # zero the parameter gradients
          optimizer.zero_grad()

          # Forward pass
          outputs = net(inputs)
          B, C, H, W = outputs.shape
          outputs = outputs.permute(0, 2, 3, 1)
          outputs = outputs.reshape(-1, C)
          labels = to_labels(labels, class_dict)
          labels = labels.long().view(-1)


          # backward + optimize
          loss = criterion(outputs, labels)
          loss.backward()
          optimizer.step()

          loop.set_description("Training")
          total_loss += loss.detach().item()
          i += 1
          loop.set_postfix(loss=total_loss / i)

      # Validate
      net.eval()
      loop = tqdm(val_loader)
      loop.set_description("Validation")
      with torch.no_grad():
        all_targets = []
        all_preds = []
        for data in loop:
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data

            # Forward pass
            outputs = net(inputs)
            B, C, H, W = outputs.shape
            outputs = outputs.permute(0, 2, 3, 1)
            outputs = outputs.reshape(-1, C)
            labels = to_labels(labels, class_dict)
            labels = labels.long().view(-1)

            # Targets and predictions for iou
            _, predicted = torch.max(outputs, 1)
            all_targets.append(labels)
            all_preds.append(predicted)
        all_preds = torch.cat(all_preds)
        all_targets = torch.cat(all_targets)
        iou, miou = IoU(all_targets, all_preds, 15)

        # print statistics
        print(f'epochs: {epoch + 1} mIoU Val: {100 * miou.item():.3f}')
  print('Finished Training')
  return net

# %%
num_classes = 15
net = UNetStudent(num_classes).to(device)
# Loss function and optimizer
lr = 0.001
num_epochs = 5
criterion = nn.CrossEntropyLoss(ignore_index=0)
optimizer = optim.Adam(net.parameters(), lr=lr, weight_decay=1e-5)

# Training the first time will take a while. After the first pass through
# the data, training will speed up.
net = train_net_iou(net, trainloader, val_loader, device, num_epochs, optimizer, criterion)
# Out:
# Training: 100%|██████████| 170/170 [02:11<00:00,  1.29it/s, loss=1.55]
# Validation: 100%|██████████| 125/125 [03:01<00:00,  1.45s/it]
# epochs: 1 mIoU Val: 12.634
# Training: 100%|██████████| 170/170 [00:10<00:00, 16.59it/s, loss=1.25]
# Validation: 100%|██████████| 125/125 [00:06<00:00, 18.03it/s]
# epochs: 2 mIoU Val: 19.125
# Training: 100%|██████████| 170/170 [00:10<00:00, 15.67it/s, loss=1.07]
# Validation: 100%|██████████| 125/125 [00:06<00:00, 19.25it/s]
# epochs: 3 mIoU Val: 10.992
# Training: 100%|██████████| 170/170 [00:11<00:00, 15.35it/s, loss=1.02]
# Validation: 100%|██████████| 125/125 [00:07<00:00, 17.71it/s]
# epochs: 4 mIoU Val: 18.771
# Training: 100%|██████████| 170/170 [00:10<00:00, 16.11it/s, loss=0.946]
# Validation: 100%|██████████| 125/125 [00:06<00:00, 18.85it/s]
# epochs: 5 mIoU Val: 15.948
# Finished Training

# %% [markdown]
# ## Save Weights
# Run the next cell to save your weights.

# %%
# Save Weights
PATH = os.path.join(DATA_PATH, 'YourNet.pth')
torch.save(net.state_dict(), PATH)

# %% [markdown]
# # Visualize predictions
# Next, we will load the saved weights and visualize some predictions compared to the ground truth.

# %%
net = UNetStudent(num_classes).to(device)
net.load_state_dict(torch.load(PATH))
# Out:
# <All keys matched successfully>

# %%
# Convert colored image to labels
def label_to_image(label_img, color_to_label):
    B, H, W = label_img.shape
    colored_img = torch.zeros((B, H, W, 3), device=label_img.device, dtype=torch.uint8)
    for i, rgb in color_to_label.items():
        mask = label_img == i
        colored_img[mask, :] = torch.tensor(rgb, device=label_img.device, dtype=torch.uint8)
    return colored_img

# %%
with torch.no_grad():
    # get some random training images
    dataiter = iter(trainloader)
    images, labels = next(dataiter)

    # Make predictions
    # Forward pass
    outputs = net(images)
    B, C, H, W = outputs.shape
    outputs = outputs.permute(0, 2, 3, 1)
    # Targets and predictions for iou
    _, predicted = torch.max(outputs, 3)
    predicted_img = label_to_image(predicted, class_dict)
    # show labels
    print("Ground Truth")
    demo_label = labels[0, :, :, :]
    imshow_labels(demo_label)
    # Show predictions
    print("Prediction")
    demo_pred = predicted_img[0, :, :, :]
    imshow_labels(demo_pred)
# Out:
# Ground Truth
# Prediction

# %% [markdown]
# ## Your Turn
# Great! That was an easy assignment so far. Now comes the tricky part though. Now it is your turn to modify the training pipeline, hyper-parameters, and network architecture to improve the performance. Below are some ideas you can try:
#
#
#
# 1.   Implement image_augmentation with random cropping and flipping.
# 2.   Add more convolution layers to each level of the U Net.
# 3.   Change the channel sizes within the U Net.
# 4.   Change the learning rate, batch size, and number of epochs.
# 5.   Add weights to the CrossEntropyLoss to weight classes with fewer occurences more.
# 6.   Modify the training code to save the model weights from the epoch with the highest mIoU on the validation set.
# 7.   There are many more options... you choose!

# %%
num_classes = 15
net = UNetStudent(num_classes).to(device)

# Hyper-parameters
lr = 0.001
num_epochs = 30
batch_size = 10

# Loss function and optimizer
criterion = nn.CrossEntropyLoss(ignore_index=0)
optimizer = optim.Adam(net.parameters(), lr=lr, weight_decay=1e-5)

# %%
trainset = ImageSegmentation(DATA_PATH, "Train", transform=transform_train(), device=device)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, collate_fn=trainset.collate_fn)

valset = ImageSegmentation(DATA_PATH, "Val", transform=transform_test(), device=device)
val_loader = torch.utils.data.DataLoader(valset, batch_size=batch_size,
                                         shuffle=True, collate_fn=valset.collate_fn)

# %%
net = train_net_iou(net, trainloader, val_loader, device, num_epochs, optimizer, criterion)
torch.save(net.state_dict(), PATH)
# Out:
# Training: 100%|██████████| 34/34 [00:11<00:00,  3.09it/s, loss=1.65]
# Validation: 100%|██████████| 25/25 [00:09<00:00,  2.73it/s]
# epochs: 1 mIoU Val: 6.610
# Training: 100%|██████████| 34/34 [00:09<00:00,  3.70it/s, loss=1.18]
# Validation: 100%|██████████| 25/25 [00:09<00:00,  2.74it/s]
# epochs: 2 mIoU Val: 17.128
# Training: 100%|██████████| 34/34 [00:09<00:00,  3.41it/s, loss=1.04]
# Validation: 100%|██████████| 25/25 [00:09<00:00,  2.71it/s]
# epochs: 3 mIoU Val: 19.937
# Training: 100%|██████████| 34/34 [00:09<00:00,  3.74it/s, loss=0.995]
# Validation: 100%|██████████| 25/25 [00:09<00:00,  2.68it/s]
# epochs: 4 mIoU Val: 21.658
# Training: 100%|██████████| 34/34 [00:10<00:00,  3.35it/s, loss=0.915]
# Validation: 100%|██████████| 25/25 [00:08<00:00,  2.78it/s]
# epochs: 5 mIoU Val: 22.134
# Training: 100%|██████████| 34/34 [00:09<00:00,  3.65it/s, loss=0.865]
# Validation: 100%|██████████| 25/25 [00:09<00:00,  2.72it/s]
# epochs: 6 mIoU Val: 19.380
# Training: 100%|██████████| 34/34 [00:09<00:00,  3.41it/s, loss=0.826]
# Validation: 100%|██████████| 25/25 [00:08<00:00,  2.86it/s]
# epochs: 7 mIoU Val: 17.639
# Training: 100%|██████████| 34/34 [00:09<00:00,  3.48it/s, loss=0.778]
# Validation: 100%|██████████| 25/25 [00:09<00:00,  2.73it/s]
# epochs: 8 mIoU Val: 17.425
# Training: 100%|██████████| 34/34 [00:10<00:00,  3.36it/s, loss=0.803]
# Validation: 100%|██████████| 25/25 [00:08<00:00,  2.87it/s]
# epochs: 9 mIoU Val: 21.243
# Training: 100%|██████████| 34/34 [00:10<00:00,  3.38it/s, loss=0.789]
# Validation: 100%|██████████| 25/25 [00:09<00:00,  2.71it/s]
# epochs: 10 mIoU Val: 23.080
# Training: 100%|██████████| 34/34 [00:10<00:00,  3.34it/s, loss=0.736]
# Validation: 100%|██████████| 25/25 [00:08<00:00,  2.87it/s]
# epochs: 11 mIoU Val: 19.419
# Training: 100%|██████████| 34/34 [00:10<00:00,  3.37it/s, loss=0.782]
# Validation: 100%|██████████| 25/25 [00:09<00:00,  2.68it/s]
# epochs: 12 mIoU Val: 15.599
# Training: 100%|██████████| 34/34 [00:09<00:00,  3.41it/s, loss=0.699]
# Validation: 100%|██████████| 25/25 [00:08<00:00,  2.87it/s]
# epochs: 13 mIoU Val: 24.652
# Training: 100%|██████████| 34/34 [00:10<00:00,  3.30it/s, loss=0.688]
# Validation: 100%|██████████| 25/25 [00:09<00:00,  2.69it/s]
# epochs: 14 mIoU Val: 20.923
# Training: 100%|██████████| 34/34 [00:10<00:00,  3.40it/s, loss=0.689]
# Validation: 100%|██████████| 25/25 [00:08<00:00,  2.85it/s]
# epochs: 15 mIoU Val: 21.268
# Training: 100%|██████████| 34/34 [00:10<00:00,  3.31it/s, loss=0.651]
# Validation: 100%|██████████| 25/25 [00:09<00:00,  2.63it/s]
# epochs: 16 mIoU Val: 23.832
# Training: 100%|██████████| 34/34 [00:09<00:00,  3.43it/s, loss=0.638]
# Validation: 100%|██████████| 25/25 [00:08<00:00,  2.86it/s]
# epochs: 17 mIoU Val: 27.966
# Training: 100%|██████████| 34/34 [00:09<00:00,  3.42it/s, loss=0.617]
# Validation: 100%|██████████| 25/25 [00:09<00:00,  2.71it/s]
# epochs: 18 mIoU Val: 17.593
# Training: 100%|██████████| 34/34 [00:09<00:00,  3.61it/s, loss=0.644]
# Validation: 100%|██████████| 25/25 [00:09<00:00,  2.77it/s]
# epochs: 19 mIoU Val: 24.844
# Training: 100%|██████████| 34/34 [00:10<00:00,  3.34it/s, loss=0.611]
# Validation: 100%|██████████| 25/25 [00:09<00:00,  2.69it/s]
# epochs: 20 mIoU Val: 21.556
# Training: 100%|██████████| 34/34 [00:09<00:00,  3.50it/s, loss=0.61]
# Validation: 100%|██████████| 25/25 [00:09<00:00,  2.78it/s]
# epochs: 21 mIoU Val: 20.949
# Training: 100%|██████████| 34/34 [00:10<00:00,  3.39it/s, loss=0.664]
# Validation: 100%|██████████| 25/25 [00:09<00:00,  2.73it/s]
# epochs: 22 mIoU Val: 23.529
# Training: 100%|██████████| 34/34 [00:09<00:00,  3.77it/s, loss=0.639]
# Validation: 100%|██████████| 25/25 [00:09<00:00,  2.72it/s]
# epochs: 23 mIoU Val: 18.301
# Training: 100%|██████████| 34/34 [00:09<00:00,  3.41it/s, loss=0.624]
# Validation: 100%|██████████| 25/25 [00:09<00:00,  2.73it/s]
# epochs: 24 mIoU Val: 22.154
# Training: 100%|██████████| 34/34 [00:09<00:00,  3.63it/s, loss=0.618]
# Validation: 100%|██████████| 25/25 [00:09<00:00,  2.71it/s]
# epochs: 25 mIoU Val: 20.351
# Training: 100%|██████████| 34/34 [00:10<00:00,  3.34it/s, loss=0.602]
# Validation: 100%|██████████| 25/25 [00:08<00:00,  2.80it/s]
# epochs: 26 mIoU Val: 19.341
# Training: 100%|██████████| 34/34 [00:09<00:00,  3.61it/s, loss=0.605]
# Validation: 100%|██████████| 25/25 [00:09<00:00,  2.68it/s]
# epochs: 27 mIoU Val: 19.182
# Training: 100%|██████████| 34/34 [00:10<00:00,  3.34it/s, loss=0.545]
# Validation: 100%|██████████| 25/25 [00:08<00:00,  2.85it/s]
# epochs: 28 mIoU Val: 18.982
# Training: 100%|██████████| 34/34 [00:09<00:00,  3.55it/s, loss=0.561]
# Validation: 100%|██████████| 25/25 [00:09<00:00,  2.67it/s]
# epochs: 29 mIoU Val: 21.073
# Training: 100%|██████████| 34/34 [00:10<00:00,  3.30it/s, loss=0.605]
# Validation: 100%|██████████| 25/25 [00:08<00:00,  2.86it/s]
# epochs: 30 mIoU Val: 21.064
# Finished Training

# %% [markdown]
# When you are happy with your results on the validation set, run the following cells to save the weights and generate predictions on the test set. The entire score from this assignment will be based on the mIoU as described above.

# %%
net = UNetStudent(num_classes).to(device)
net.load_state_dict(torch.load(PATH))
# Out:
# <All keys matched successfully>

# %%
testset = ImageSegmentation(DATA_PATH, "Test", transform=transform_test(), device=device)

# %%
# Test
i = 0
net.eval()
save_dir = os.path.join(DATA_PATH, "Test", "Problem2_Predictions")
if not os.path.exists(save_dir):
  os.mkdir(save_dir)

i = 0
with torch.no_grad():
  for inputs, __ in iter(testset):
    # We are only evaluating every tenth image due to memory constraints on
    # Auto-grader
    if i % 10 == 0:
      C, H, W = inputs.shape
      outputs = net(inputs.view(1, C, H, W).to(device))
      B, C, H, W = outputs.shape
      outputs = outputs.permute(0, 2, 3, 1)
      predictions = outputs.argmax(dim=3).view(H, W)
      predictions_np = predictions.detach().cpu().numpy().astype(np.uint8)
      save_path = os.path.join(save_dir, str(i).zfill(6) + ".label")
      predictions_np.tofile(save_path)
    i += 1

# %% [markdown]
# # Submission
# Great job! Submit the predictions folder as a zip file called `Problem2_Predictions.zip`, as well as your solution file `Problem2.py`.
